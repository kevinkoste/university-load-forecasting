# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

import xgboost as xgb
from xgboost import plot_importance, plot_tree

import utility_functions as fn

# %%
energy = pd.read_csv('energy_clean.csv',index_col=0)
energy.index = pd.to_datetime(energy.index,format='%Y-%m-%d %H:00:00')

energy['Yale_kW']= energy.iloc[:, 0:11].sum(axis=1)
energy = pd.DataFrame(energy['Yale_kW'])

# %%
weather = pd.read_csv('weather_clean.csv',index_col=0)
weather.index = pd.to_datetime(weather.index,format='%Y-%m-%d %H:00:00')

weather = fn.add_hours_before(weather,np.arange(1,24))
weather = weather.loc[energy.index[0]:energy.index[len(energy)-1]]

# %%
# dates = pd.read_csv('date_features.csv',index_col=0)
# dates.index = pd.to_datetime(dates.index,format='%Y-%m-%d %H:00:00')
# dates = dates.loc[energy.index[0]:energy.index[len(energy)-1]]

dates = fn.date_features(energy)
# Out:
#                      hour  dayofweek  quarter  month  year  dayofyear  \
# 2018-01-01 01:00:00     1          0        1      1  2018          1
# 2018-01-01 02:00:00     2          0        1      1  2018          1
# 2018-01-01 03:00:00     3          0        1      1  2018          1
# 2018-01-01 04:00:00     4          0        1      1  2018          1
# 2018-01-01 05:00:00     5          0        1      1  2018          1
# 2018-01-01 06:00:00     6          0        1      1  2018          1
# 2018-01-01 07:00:00     7          0        1      1  2018          1
# 2018-01-01 08:00:00     8          0        1      1  2018          1
# 2018-01-01 09:00:00     9          0        1      1  2018          1
# 2018-01-01 10:00:00    10          0        1      1  2018          1
# 2018-01-01 11:00:00    11          0        1      1  2018          1
# 2018-01-01 12:00:00    12          0        1      1  2018          1
# 2018-01-01 13:00:00    13          0        1      1  2018          1
# 2018-01-01 14:00:00    14          0        1      1  2018          1
# 2018-01-01 15:00:00    15          0        1      1  2018          1
# 2018-01-01 16:00:00    16          0        1      1  2018          1
# 2018-01-01 17:00:00    17          0        1      1  2018          1
# 2018-01-01 18:00:00    18          0        1      1  2018          1
# 2018-01-01 19:00:00    19          0        1      1  2018          1
# 2018-01-01 20:00:00    20          0        1      1  2018          1
# 2018-01-01 21:00:00    21          0        1      1  2018          1
# 2018-01-01 22:00:00    22          0        1      1  2018          1
# 2018-01-01 23:00:00    23          0        1      1  2018          1
# 2018-01-02 00:00:00     0          1        1      1  2018          2
# 2018-01-02 01:00:00     1          1        1      1  2018          2
# 2018-01-02 02:00:00     2          1        1      1  2018          2
# 2018-01-02 03:00:00     3          1        1      1  2018          2
# 2018-01-02 04:00:00     4          1        1      1  2018          2
# 2018-01-02 05:00:00     5          1        1      1  2018          2
# 2018-01-02 06:00:00     6          1        1      1  2018          2
# ...                   ...        ...      ...    ...   ...        ...
# 2018-07-26 18:00:00    18          3        3      7  2018        207
# 2018-07-26 19:00:00    19          3        3      7  2018        207
# 2018-07-26 20:00:00    20          3        3      7  2018        207
# 2018-07-26 21:00:00    21          3        3      7  2018        207
# 2018-07-26 22:00:00    22          3        3      7  2018        207
# 2018-07-26 23:00:00    23          3        3      7  2018        207
# 2018-07-27 00:00:00     0          4        3      7  2018        208
# 2018-07-27 08:00:00          27          30
# 2018-07-27 09:00:00          27          30
# 2018-07-27 10:00:00          27          30
# 2018-07-27 11:00:00          27          30
# 2018-07-27 12:00:00          27          30
# 2018-07-27 13:00:00          27          30
# 2018-07-27 14:00:00          27          30
# 2018-07-27 15:00:00          27          30
# 2018-07-27 16:00:00          27          30
# 2018-07-27 17:00:00          27          30
# 2018-07-27 18:00:00          27          30
# 2018-07-27 19:00:00          27          30
# 2018-07-27 20:00:00          27          30
# 2018-07-27 21:00:00          27          30
# 2018-07-27 22:00:00          27          30
# 2018-07-27 23:00:00          27          30
#
# [4991 rows x 8 columns]

# %%
split_date = '2018-07-26 00:00:00'

weather_train = weather.loc[weather.index <= split_date].copy()
weather_test = weather.loc[weather.index > split_date].copy()

dates_train = dates.loc[dates.index <= split_date].copy()
dates_test = dates.loc[dates.index <= split_date].copy()

# %%
X_train = weather_train.join(dates_train)
X_test = weather_test.join(dates_test)

y_train = energy.loc[energy.index <= split_date].copy()
y_test = energy.loc[energy.index > split_date].copy()

# %%
weather.describe()
# Out:
#               temp         tmin         tmax     pressure     humidity  \
# count  4991.000000  4991.000000  4991.000000  4991.000000  4991.000000
# mean    283.161562   281.006758   285.086903  1017.521038    72.276197
# std      10.263122    10.241124    10.415621     8.607309    21.180297
# min     253.940000   247.150000   257.150000   983.000000    10.000000
# 25%     275.355000   274.150000   277.150000  1012.000000    56.000000
# 50%     282.480000   280.150000   284.150000  1017.000000    75.000000
# 75%     291.680000   289.150000   294.150000  1022.000000    93.000000
# max     306.410000   304.150000   309.150000  1044.000000   100.000000
#
#               wind       clouds    rain    snow       temp-1   ...     \
# count  4991.000000  4991.000000  4991.0  4991.0  4991.000000   ...
# mean      3.285113    40.776999     0.0     0.0   283.153816   ...
# std       2.012257    41.369641     0.0     0.0    10.265626   ...
# min       0.000000     0.000000     0.0     0.0   253.940000   ...
# 25%       2.000000     1.000000     0.0     0.0   275.350000   ...
# 50%       3.000000    20.000000     0.0     0.0   282.470000   ...
# 75%       4.000000    90.000000     0.0     0.0   291.665000   ...
# max      15.000000    92.000000     0.0     0.0   306.410000   ...
#
#        snow-22      temp-23      tmin-23      tmax-23  pressure-23  \
# count   4991.0  4991.000000  4991.000000  4991.000000  4991.000000
# mean       0.0   283.153816   280.998944   285.078888  1017.522841
# std        0.0    10.265626    10.243682    10.418647     8.607933
# min        0.0   253.940000   247.150000   257.150000   983.000000
# 25%        0.0   275.350000   274.150000   277.150000  1012.000000
# 50%        0.0   282.470000   280.150000   284.150000  1017.000000
# 75%        0.0   291.665000   289.150000   294.150000  1022.000000
# max        0.0   306.410000   304.150000   309.150000  1044.000000
#
#        humidity-23      wind-23    clouds-23  rain-23  snow-23
# count  4991.000000  4991.000000  4991.000000   4991.0   4991.0
# mean     72.268383     3.284712    40.759166      0.0      0.0
# std      21.179475     2.011915    41.367601      0.0      0.0
# min      10.000000     0.000000     0.000000      0.0      0.0
# 25%      56.000000     2.000000     1.000000      0.0      0.0
# 50%      75.000000     3.000000    20.000000      0.0      0.0
# 75%      93.000000     4.000000    90.000000      0.0      0.0
# max     100.000000    15.000000    92.000000      0.0      0.0
#
# [8 rows x 216 columns]

# %%
reg = xgb.XGBRegressor(n_estimators=1000)
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        early_stopping_rounds=50,
        verbose=False)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=1000,
#        n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)

# %%
_ = plot_importance(reg, height=0.9)

# %%
y_test['Prediction_kW'] = reg.predict(X_test)
yale_all = pd.concat([y_test, y_train], sort=False)
_ = yale_all[['Yale_kW','Prediction_kW']].plot(figsize=(15, 5))

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    """Calculates MAPE given y_true and y_pred"""
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
mean_absolute_percentage_error(y_true=y_test['Yale_kW'], y_pred=y_test['Prediction_kW'])
# Out:
# 17.5966479335007

# %%
y_test
# Out:
#                      Yale_kW  Prediction_kW
# 2018-07-26 01:00:00    648.1     766.038635
# 2018-07-26 02:00:00    595.1     766.038635
# 2018-07-26 03:00:00    659.4     766.038635
# 2018-07-26 04:00:00    628.8     766.038635
# 2018-07-26 05:00:00    639.4     766.038635
# 2018-07-26 06:00:00    619.7     766.038635
# 2018-07-26 07:00:00    685.2     766.038635
# 2018-07-26 08:00:00    748.7     766.038635
# 2018-07-26 09:00:00    867.8     766.038635
# 2018-07-26 10:00:00    929.4     766.038635
# 2018-07-26 11:00:00   1001.2     766.038635
# 2018-07-26 12:00:00    983.1     766.038635
# 2018-07-26 13:00:00   1005.2     766.038635
# 2018-07-26 14:00:00    981.9     766.038635
# 2018-07-26 15:00:00    953.6     766.038635
# 2018-07-26 16:00:00    955.2     766.038635
# 2018-07-26 17:00:00   1001.0     766.038635
# 2018-07-26 18:00:00    970.2     766.038635
# 2018-07-26 19:00:00    955.8     766.038635
# 2018-07-26 20:00:00    860.2     766.038635
# 2018-07-26 21:00:00    821.9     766.038635
# 2018-07-26 22:00:00    695.1     766.038635
# 2018-07-26 23:00:00    702.8     766.038635
# 2018-07-27 00:00:00    660.2     766.038635
# 2018-07-27 01:00:00    680.3     766.038635
# 2018-07-27 02:00:00    580.2     766.038635
# 2018-07-27 03:00:00    639.1     766.038635
# 2018-07-27 04:00:00    633.5     766.038635
# 2018-07-27 05:00:00    624.3     766.038635
# 2018-07-27 06:00:00    605.6     766.038635
# 2018-07-27 07:00:00    688.1     766.038635
# 2018-07-27 08:00:00    737.2     766.038635
# 2018-07-27 09:00:00    862.9     766.038635
# 2018-07-27 10:00:00    927.6     766.038635
# 2018-07-27 11:00:00    999.1     766.038635
# 2018-07-27 12:00:00    990.1     766.038635
# 2018-07-27 13:00:00   1024.2     766.038635
# 2018-07-27 14:00:00    995.6     766.038635
# 2018-07-27 15:00:00   1003.7     766.038635
# 2018-07-27 16:00:00    985.9     766.038635
# 2018-07-27 17:00:00    963.8     766.038635
# 2018-07-27 18:00:00    963.7     766.038635
# 2018-07-27 19:00:00    899.4     766.038635
# 2018-07-27 20:00:00    806.5     766.038635
# 2018-07-27 21:00:00    742.4     766.038635
# 2018-07-27 22:00:00    702.1     766.038635
# 2018-07-27 23:00:00    664.6     766.038635
